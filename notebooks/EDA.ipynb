# %%
import pandas as pd
import numpy as np
import glob

# Path to your raw folder
#path = "../data/raw/"

# Get all CSV files inside raw folder
#files = glob.glob(path + "*.csv")

#dfs = []

#for f in files:
   # print("Loading:", f)
   # df = pd.read_csv(f, sep=";")   # IMPORTANT: GeodAir uses semicolon
   # dfs.append(df)

# Combine all files
#df_raw = pd.concat(dfs, ignore_index=True)

# Save combined dataset INSIDE raw folder
#df_raw.to_csv("../data/raw/Airquality_PACA_2025_Combined.csv", index=False)

#df_raw.shape

# Load final combined dataset
combined_path = "../data/raw/Airquality_PACA_2025_Combined.csv"

df_raw= pd.read_csv(combined_path)

print("Loaded combined dataset:", df_raw.shape)
df_raw.head()
# Out:
# Loaded combined dataset: (734708, 23)
#          Date de début          Date de fin Organisme   code zas  \
# 0  2025-04-01 00:00:00  2025-04-01 01:00:00  ATMO SUD  FR93ZAG01
# 1  2025-04-01 01:00:00  2025-04-01 02:00:00  ATMO SUD  FR93ZAG01
# 2  2025-04-01 02:00:00  2025-04-01 03:00:00  ATMO SUD  FR93ZAG01
# 3  2025-04-01 03:00:00  2025-04-01 04:00:00  ATMO SUD  FR93ZAG01
# 4  2025-04-01 04:00:00  2025-04-01 05:00:00  ATMO SUD  FR93ZAG01
#
#                  Zas code site            nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 1  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 2  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 3  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 4  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# ...

# %%
# import os
# import glob
# import pandas as pd

# combined_path = "../data/raw/Airquality_PACA_2025_Combined.csv"

# if not os.path.exists(combined_path):
#     print("Combined file not found — creating it now...")

#     monthly_files = glob.glob("../data/raw/*_Analysis.csv")
#     dfs = []

#     for f in monthly_files:
#         print("Loading:", f)
#         df = pd.read_csv(f, sep=";")   # IMPORTANT: Geodair uses semicolon
#         dfs.append(df)

#     df_all = pd.concat(dfs, ignore_index=True)
#     df_all.to_csv(combined_path, index=False)

# else:
#     print("Combined dataset already exists — skipping creation.")

# df = pd.read_csv(combined_path)
# print("Loaded:", df.shape)

# %%
df_raw.head()
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2025-04-01 00:00:00  2025-04-01 01:00:00  ATMO SUD  FR93ZAG01
# 1  2025-04-01 01:00:00  2025-04-01 02:00:00  ATMO SUD  FR93ZAG01
# 2  2025-04-01 02:00:00  2025-04-01 03:00:00  ATMO SUD  FR93ZAG01
# 3  2025-04-01 03:00:00  2025-04-01 04:00:00  ATMO SUD  FR93ZAG01
# 4  2025-04-01 04:00:00  2025-04-01 05:00:00  ATMO SUD  FR93ZAG01
#
#                  Zas code site            nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 1  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 2  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 3  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 4  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0     PM10     Industrielle  ...   12.0       12.000           µg-m3
# ...

# %%
df_april = pd.read_csv("../data/raw/April_Analysis.csv",sep=";")
df_april
# Out:
#              Date de début          Date de fin Organisme   code zas  \
# 0      2025-04-01 00:00:00  2025-04-01 01:00:00  ATMO SUD  FR93ZAG01
# 1      2025-04-01 01:00:00  2025-04-01 02:00:00  ATMO SUD  FR93ZAG01
# 2      2025-04-01 02:00:00  2025-04-01 03:00:00  ATMO SUD  FR93ZAG01
# 3      2025-04-01 03:00:00  2025-04-01 04:00:00  ATMO SUD  FR93ZAG01
# 4      2025-04-01 04:00:00  2025-04-01 05:00:00  ATMO SUD  FR93ZAG01
# ...                    ...                  ...       ...        ...
# 69445  2025-04-29 19:00:00  2025-04-29 20:00:00  ATMO SUD  FR93ZRE02
# 69446  2025-04-29 20:00:00  2025-04-29 21:00:00  ATMO SUD  FR93ZRE02
# 69447  2025-04-29 21:00:00  2025-04-29 22:00:00  ATMO SUD  FR93ZRE02
# 69448  2025-04-29 22:00:00  2025-04-29 23:00:00  ATMO SUD  FR93ZRE02
# 69449  2025-04-29 23:00:00  2025-04-30 00:00:00  ATMO SUD  FR93ZRE02
#
#                                  Zas code site            nom site  \
# 0                  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque
# ...

# %%
df_raw=pd.read_csv("../data/raw/Airquality_PACA_2025_Combined.csv", sep=",")
df_raw.head()
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2025-04-01 00:00:00  2025-04-01 01:00:00  ATMO SUD  FR93ZAG01
# 1  2025-04-01 01:00:00  2025-04-01 02:00:00  ATMO SUD  FR93ZAG01
# 2  2025-04-01 02:00:00  2025-04-01 03:00:00  ATMO SUD  FR93ZAG01
# 3  2025-04-01 03:00:00  2025-04-01 04:00:00  ATMO SUD  FR93ZAG01
# 4  2025-04-01 04:00:00  2025-04-01 05:00:00  ATMO SUD  FR93ZAG01
#
#                  Zas code site            nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 1  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 2  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 3  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
# 4  ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0     PM10     Industrielle  ...   12.0       12.000           µg-m3
# ...

# %%
df_sample = df_raw.sample(frac=0.20, random_state=42)
df_sample.to_csv("../data/sample/Airquality_PACA_sample.csv", index=False)

# %%
df_sample.head()
# Out:
#               Date de début          Date de fin Organisme   code zas  \
# 337888  2025-07-09 23:00:00  2025-07-10 00:00:00  ATMO SUD  FR93ZRE02
# 469825  2025-03-30 12:00:00  2025-03-30 13:00:00  ATMO SUD  FR93ZRE02
# 366165  2025-06-02 04:00:00  2025-06-02 05:00:00  ATMO SUD  FR93ZAG03
# 250011  2025-01-12 10:00:00  2025-01-12 11:00:00  ATMO SUD  FR93ZAG01
# 723425  2025-09-10 21:00:00  2025-09-10 22:00:00  ATMO SUD  FR93ZAG03
#
#                                   Zas code site             nom site  \
# 337888  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03086                  APT
# 469825  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24038      GAP JEAN JAURES
# 366165                     ZAG TOULON   FR03071        TOULON CLARET
# 250011              ZAG MARSEILLE-AIX   FR03006    MARSEILLE RABATAU
# 723425                     ZAG TOULON   FR03064  LA VALETTE/LA GARDE
#
#        type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# ...

# %%
df_sample.columns
# Out:
# Index(['Date de début', 'Date de fin', 'Organisme', 'code zas', 'Zas',
#        'code site', 'nom site', 'type d'implantation', 'Polluant',
#        'type d'influence', 'Réglementaire', 'type d'évaluation',
#        'type de valeur', 'valeur', 'valeur brute', 'unité de mesure',
#        'taux de saisie', 'couverture temporelle', 'couverture de données',
#        'code qualité', 'validité', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146942 entries, 337888 to 586192
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date de début          146942 non-null  object
#  1   Date de fin            146942 non-null  object
#  2   Organisme              146942 non-null  object
#  3   code zas               146942 non-null  object
#  4   Zas                    146942 non-null  object
#  5   code site              146942 non-null  object
#  6   nom site               146942 non-null  object
#  7   type d'implantation    146942 non-null  object
#  8   Polluant               146942 non-null  object
#  9   type d'influence       146942 non-null  object
#  10  Réglementaire          146942 non-null  object
#  11  type d'évaluation      146942 non-null  object
#  12  type de valeur         146942 non-null  object
#  13  valeur                 142620 non-null  float64
# ...

# %%
df_sample.head(10)
# Out:
#               Date de début          Date de fin Organisme   code zas  \
# 337888  2025-07-09 23:00:00  2025-07-10 00:00:00  ATMO SUD  FR93ZRE02
# 469825  2025-03-30 12:00:00  2025-03-30 13:00:00  ATMO SUD  FR93ZRE02
# 366165  2025-06-02 04:00:00  2025-06-02 05:00:00  ATMO SUD  FR93ZAG03
# 250011  2025-01-12 10:00:00  2025-01-12 11:00:00  ATMO SUD  FR93ZAG01
# 723425  2025-09-10 21:00:00  2025-09-10 22:00:00  ATMO SUD  FR93ZAG03
# 560356  2025-11-03 15:00:00  2025-11-03 16:00:00  ATMO SUD  FR93ZRE02
# 215783  2025-01-17 06:00:00  2025-01-17 07:00:00  ATMO SUD  FR93ZRE02
# 534512  2025-05-19 19:00:00  2025-05-19 20:00:00  ATMO SUD  FR93ZRE02
# 179319  2025-02-15 21:00:00  2025-02-15 22:00:00  ATMO SUD  FR93ZAG01
# 99624   2025-08-30 06:00:00  2025-08-30 07:00:00  ATMO SUD  FR93ZAG02
#
#                                   Zas code site              nom site  \
# 337888  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03086                   APT
# ...

# %%
df_sample.tail(10)
# Out:
#               Date de début          Date de fin Organisme   code zas  \
# 212940  2025-01-12 19:00:00  2025-01-12 20:00:00  ATMO SUD  FR93ZRE02
# 708123  2025-09-14 07:00:00  2025-09-14 08:00:00  ATMO SUD  FR93ZAG01
# 634555  2025-10-03 23:00:00  2025-10-04 00:00:00  ATMO SUD  FR93ZAG01
# 483797  2025-03-22 16:00:00  2025-03-22 17:00:00  ATMO SUD  FR93ZAG01
# 3775    2025-04-07 22:00:00  2025-04-07 23:00:00  ATMO SUD  FR93ZAG03
# 161958  2025-02-16 12:00:00  2025-02-16 13:00:00  ATMO SUD  FR93ZAG03
# 25423   2025-04-17 22:00:00  2025-04-17 23:00:00  ATMO SUD  FR93ZAG02
# 52762   2025-04-01 01:00:00  2025-04-01 02:00:00  ATMO SUD  FR93ZRE02
# 183000  2025-02-20 06:00:00  2025-02-20 07:00:00  ATMO SUD  FR93ZAG03
# 586192  2025-11-12 11:00:00  2025-11-12 12:00:00  ATMO SUD  FR93ZAG01
#
#                                   Zas code site             nom site  \
# 212940  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03070              ESTEREL
# ...

# %%
df_sample.describe().T
# Out:
#                           count       mean        std        min        25%  \
# valeur                 142620.0  27.638195  30.269204  -3.000000   6.900000
# valeur brute           142620.0  27.627536  30.268314  -2.975000   6.925000
# taux de saisie              0.0        NaN        NaN        NaN        NaN
# couverture temporelle       0.0        NaN        NaN        NaN        NaN
# couverture de données       0.0        NaN        NaN        NaN        NaN
# validité               146942.0   1.299193   1.049857  -1.000000   1.000000
# Latitude               146942.0  43.626982   0.381255  43.101565  43.348048
# Longitude              146942.0   5.800729   0.812133   4.629210   5.171939
#
#                              50%        75%         max
# valeur                 14.100000  37.400000  318.000000
# valeur brute           14.075000  37.427082  317.950000
# taux de saisie               NaN        NaN         NaN
# couverture temporelle        NaN        NaN         NaN
# ...

# %%
df_sample.describe(include="object")
# Out:
#               Date de début          Date de fin Organisme   code zas  \
# count                146942               146942    146942     146942
# unique                 7508                 7508         2          5
# top     2025-10-16 13:00:00  2025-10-16 14:00:00  ATMO SUD  FR93ZAG01
# freq                     38                   38    145421      54482
#
#                       Zas code site             nom site type d'implantation  \
# count              146942    146942               146942              146942
# unique                  5        47                   47                   5
# top     ZAG MARSEILLE-AIX   FR03043  MARSEILLE 5 AVENUES             Urbaine
# freq                54482      7523                 7523               98862
#
#        Polluant type d'influence Réglementaire type d'évaluation  \
# count    146942           146942        146942            146942
# unique        5                3             1                 2
# ...

# %%
df_sample.isna().sum().sort_values(ascending=False)
# Out:
# taux de saisie           146942
# couverture de données    146942
# couverture temporelle    146942
# valeur                     4322
# valeur brute               4322
# Date de fin                   0
# Date de début                 0
# nom site                      0
# code site                     0
# Zas                           0
# code zas                      0
# Organisme                     0
# Réglementaire                 0
# type d'implantation           0
# Polluant                      0
# type d'évaluation             0
# type de valeur                0
# type d'influence              0
# unité de mesure               0
# code qualité                  0
# validité                      0
# Latitude                      0
# Longitude                     0
# dtype: int64

# %%
df_sample.loc[df_sample["valeur"] < 0, "valeur"].sum()
# Out:
# np.float64(-310.5)

# %%
#Replacing the negative values with Nan
df_sample.loc[df_sample["valeur"] < 0, "valeur"] = np.nan
#df_sample["valeur"] = df_sample["valeur"].mask(df_sample["valeur"] < 0)

# %%
df_sample.describe().T
# Out:
#                           count       mean        std        min        25%  \
# valeur                 142283.0  27.705839  30.273045   0.000000   7.000000
# valeur brute           142620.0  27.627536  30.268314  -2.975000   6.925000
# taux de saisie              0.0        NaN        NaN        NaN        NaN
# couverture temporelle       0.0        NaN        NaN        NaN        NaN
# couverture de données       0.0        NaN        NaN        NaN        NaN
# validité               146942.0   1.299193   1.049857  -1.000000   1.000000
# Latitude               146942.0  43.626982   0.381255  43.101565  43.348048
# Longitude              146942.0   5.800729   0.812133   4.629210   5.171939
#
#                              50%        75%         max
# valeur                 14.100000  37.600000  318.000000
# valeur brute           14.075000  37.427082  317.950000
# taux de saisie               NaN        NaN         NaN
# couverture temporelle        NaN        NaN         NaN
# ...

# %%
df_sample.loc[df_sample["valeur"] < 0, "valeur"].sum()
# Out:
# np.float64(0.0)

# %%
neg_count = (df_sample["valeur"] < 0).sum()
print("Negative 'valeur' count (before fix):", int(neg_count))
# Out:
# Negative 'valeur' count (before fix): 0

# %%
missing_valeur = df_sample["valeur"].isna().sum()
missing_percent_valeur = (missing_valeur/len(df_sample["valeur"]))*100
print(f"Missing 'valeur' count: {missing_valeur}({missing_percent_valeur:.2f}%)")
# Out:
# Missing 'valeur' count: 4659(3.17%)

# %%
missing = df_sample.isna().sum()
missing_percent = (missing/len(df_sample))*100
missing_percent.sort_values(ascending=False)
missing_df = pd.DataFrame({"missing count": missing, "missing percent":missing_percent})
missing_df.sort_values(by ="missing percent",ascending=False)
# Out:
#                        missing count  missing percent
# taux de saisie                146942       100.000000
# couverture de données         146942       100.000000
# couverture temporelle         146942       100.000000
# valeur                          4659         3.170639
# valeur brute                    4322         2.941297
# Date de fin                        0         0.000000
# Date de début                      0         0.000000
# nom site                           0         0.000000
# code site                          0         0.000000
# Zas                                0         0.000000
# code zas                           0         0.000000
# Organisme                          0         0.000000
# Réglementaire                      0         0.000000
# type d'implantation                0         0.000000
# Polluant                           0         0.000000
# type d'évaluation                  0         0.000000
# ...

# %%
df_sample.nunique()
# Out:
# Date de début            7508
# Date de fin              7508
# Organisme                   2
# code zas                    5
# Zas                         5
# code site                  47
# nom site                   47
# type d'implantation         5
# Polluant                    5
# type d'influence            3
# Réglementaire               1
# type d'évaluation           2
# type de valeur              2
# valeur                   1939
# valeur brute             8043
# unité de mesure             2
# taux de saisie              0
# couverture temporelle       0
# couverture de données       0
# code qualité                3
# validité                    3
# Latitude                   47
# Longitude                  47
# dtype: int64

# %%
##DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Select only the numerical columns of interest for the pairplot
numerical_cols = ['valeur', 'valeur brute', 'Latitude', 'Longitude']
sns.pairplot(df_sample[numerical_cols])
plt.show()

# %%
sns.histplot(df_sample["valeur"], bins=50, kde=True)
# Out:
# <Axes: xlabel='valeur', ylabel='Count'>

# %%
df_sample["valeur"].skew()
# Out:
# np.float64(1.536821231162296)

# %%
df_sample["valeur_log"] = np.log1p(df_sample["valeur"])

# %%
df_sample["valeur_log"].skew()
# Out:
# np.float64(0.03147118549134721)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.boxplot(x=df_sample["valeur"])
plt.title("Boxplot of valeur (Pollutant Values)")
plt.show()

# %%
df_sample["valeur"].describe().T
# Out:
# count    142283.000000
# mean         27.705839
# std          30.273045
# min           0.000000
# 25%           7.000000
# 50%          14.100000
# 75%          37.600000
# max         318.000000
# Name: valeur, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.boxplot(x=df_sample["valeur_log"])
plt.title("Boxplot of valeur (Pollutant Values)")
plt.show()

# %%
df_sample["valeur_log"].describe().T
# Out:
# count    142283.000000
# mean          2.832074
# std           1.052681
# min           0.000000
# 25%           2.079442
# 50%           2.714695
# 75%           3.653252
# max           5.765191
# Name: valeur_log, dtype: float64

# %%
cols_to_drop = [
    "valeur brute",
    "taux de saisie",
    "couverture temporelle",
    "couverture de données",
     "code zas", "nom site", "Organisme"
]

df_sample = df_sample.drop(columns=cols_to_drop, errors='ignore')

# %%
df_sample
# Out:
#               Date de début          Date de fin  \
# 337888  2025-07-09 23:00:00  2025-07-10 00:00:00
# 469825  2025-03-30 12:00:00  2025-03-30 13:00:00
# 366165  2025-06-02 04:00:00  2025-06-02 05:00:00
# 250011  2025-01-12 10:00:00  2025-01-12 11:00:00
# 723425  2025-09-10 21:00:00  2025-09-10 22:00:00
# ...                     ...                  ...
# 161958  2025-02-16 12:00:00  2025-02-16 13:00:00
# 25423   2025-04-17 22:00:00  2025-04-17 23:00:00
# 52762   2025-04-01 01:00:00  2025-04-01 02:00:00
# 183000  2025-02-20 06:00:00  2025-02-20 07:00:00
# 586192  2025-11-12 11:00:00  2025-11-12 12:00:00
#
#                                   Zas code site type d'implantation Polluant  \
# 337888  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03086         Périurbaine       O3
# 469825  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24038             Urbaine    PM2.5
# 366165                     ZAG TOULON   FR03071             Urbaine      NO2
# ...

# %%
df_sample.columns
# Out:
# Index(['Date de début', 'Date de fin', 'Zas', 'code site',
#        'type d'implantation', 'Polluant', 'type d'influence', 'Réglementaire',
#        'type d'évaluation', 'type de valeur', 'valeur', 'unité de mesure',
#        'code qualité', 'validité', 'Latitude', 'Longitude', 'valeur_log'],
#       dtype='object')

# %%
for col in df_sample.columns:
    print(col)
# Out:
# Date de début
# Date de fin
# Zas
# code site
# type d'implantation
# Polluant
# type d'influence
# Réglementaire
# type d'évaluation
# type de valeur
# valeur
# unité de mesure
# code qualité
# validité
# Latitude
# Longitude
# valeur_log

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_cols = df_sample.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10,6))
sns.heatmap(numeric_cols.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
##HYPOTHESIS TESTING

# %%
from scipy import stats
import numpy as np

# Make valeur numeric
#df['valeur'] = pd.to_numeric(df['valeur'], errors='coerce')
#df.loc[df['valeur'] < 0, 'valeur'] = np.nan  # remove invalid values

# Two groups
urban = df_sample[df_sample["type d'implantation"]=="Urbaine"]['valeur'].dropna()
peri = df_sample[df_sample["type d'implantation"]=="Périurbaine"]['valeur'].dropna()

# Hypothesis test
t_stat, p_val = stats.ttest_ind(urban, peri, equal_var=False)

print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# t-statistic: -62.9646229272596
# p-value: 0.0

# %%
pm10 = df_sample[df_sample["Polluant"]=="PM10"]["valeur"].dropna()
o3 = df_sample[df_sample["Polluant"]=="O3"]["valeur"].dropna()

t_stat, p_val = stats.ttest_ind(pm10, o3, equal_var=False)
print(p_val)
# Out:
# 0.0

# %%
##FEATURE ENGINEERING

# %%
df_sample["date"] = pd.to_datetime(df_sample["Date de début"])

# %%
#TIME FEATURES EXTRACION
df_sample["hour"] = df_sample["date"].dt.hour
df_sample["day"] = df_sample["date"].dt.day
df_sample["month"] = df_sample["date"].dt.month
df_sample["year"] = df_sample["date"].dt.year
df_sample["weekday"] = df_sample["date"].dt.weekday     # 0=Mon, 6=Sun
df_sample["is_weekend"] = df_sample["weekday"].isin([5,6]).astype(int)

df_sample["week_of_year"] = df_sample["date"].dt.isocalendar().week
df_sample["day_of_year"] = df_sample["date"].dt.dayofyear

# %%
season_map = {
    12: "winter", 1: "winter", 2: "winter",
    3: "spring", 4: "spring", 5: "spring",
    6: "summer", 7: "summer", 8: "summer",
    9: "autumn", 10: "autumn", 11: "autumn"
}
df_sample["season"] = df_sample["month"].map(season_map)

# %%
def get_time_of_day(hour):
    if 5 <= hour < 12:
        return "morning"
    elif 12 <= hour < 17:
        return "afternoon"
    elif 17 <= hour < 21:
        return "evening"
    else:
        return "night"
df_sample["time_of_day"] = df_sample["hour"].apply(get_time_of_day)
df_sample.head()
# Out:
#               Date de début          Date de fin  \
# 337888  2025-07-09 23:00:00  2025-07-10 00:00:00
# 469825  2025-03-30 12:00:00  2025-03-30 13:00:00
# 366165  2025-06-02 04:00:00  2025-06-02 05:00:00
# 250011  2025-01-12 10:00:00  2025-01-12 11:00:00
# 723425  2025-09-10 21:00:00  2025-09-10 22:00:00
#
#                                   Zas code site type d'implantation Polluant  \
# 337888  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03086         Périurbaine       O3
# 469825  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24038             Urbaine    PM2.5
# 366165                     ZAG TOULON   FR03071             Urbaine      NO2
# 250011              ZAG MARSEILLE-AIX   FR03006             Urbaine    PM2.5
# 723425                     ZAG TOULON   FR03064         Périurbaine       O3
#
#        type d'influence Réglementaire type d'évaluation  \
# 337888             Fond           Oui     mesures fixes
# 469825           Trafic           Oui     mesures fixes
# ...

# %%
df_sample["time_of_day"].value_counts()
# Out:
# time_of_day
# night        48932
# morning      43097
# afternoon    30584
# evening      24329
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
pollutant_le = LabelEncoder()
pollutant_le.fit(df_sample["Polluant"].astype(str))
df_sample["Polluant_encoded"]=pollutant_le.transform(df_sample["Polluant"].astype(str))

# %%
df_sample[["Polluant", "Polluant_encoded"]].head()
# Out:
#        Polluant  Polluant_encoded
# 337888       O3                 2
# 469825    PM2.5                 4
# 366165      NO2                 1
# 250011    PM2.5                 4
# 723425       O3                 2

# %%
influence_le = LabelEncoder()
influence_le.fit(df_sample["type d\'influence"].astype(str))
df_sample["influence_encoded"]=influence_le.transform(df_sample["type d\'influence"].astype(str))
df_sample[["type d\'influence", "influence_encoded"]]
# Out:
#        type d'influence  influence_encoded
# 337888             Fond                  0
# 469825           Trafic                  2
# 366165             Fond                  0
# 250011           Trafic                  2
# 723425             Fond                  0
# ...                 ...                ...
# 161958             Fond                  0
# 25423              Fond                  0
# 52762              Fond                  0
# 183000             Fond                  0
# 586192             Fond                  0
#
# [146942 rows x 2 columns]

# %%
implantation_le = LabelEncoder()
implantation_le.fit(df_sample["type d\'implantation"].astype(str))
df_sample["implantation_encoded"]=implantation_le.transform(df_sample["type d\'implantation"].astype(str))
df_sample[["type d\'implantation", "implantation_encoded"]]
# Out:
#        type d'implantation  implantation_encoded
# 337888         Périurbaine                     0
# 469825             Urbaine                     4
# 366165             Urbaine                     4
# 250011             Urbaine                     4
# 723425         Périurbaine                     0
# ...                    ...                   ...
# 161958             Urbaine                     4
# 25423          Périurbaine                     0
# 52762          Périurbaine                     0
# 183000             Urbaine                     4
# 586192             Urbaine                     4
#
# [146942 rows x 2 columns]

# %%
site_le = LabelEncoder()
site_le.fit(df_sample["code site"].astype(str))
df_sample["site_encoded"] = site_le.transform(df_sample["code site"].astype(str))
df_sample[["code site", "site_encoded"]]
# Out:
#        code site  site_encoded
# 337888   FR03086            30
# 469825   FR24038            44
# 366165   FR03071            27
# 250011   FR03006            12
# 723425   FR03064            23
# ...          ...           ...
# 161958   FR03071            27
# 25423    FR24007            34
# 52762    FR03070            26
# 183000   FR03071            27
# 586192   FR03043            20
#
# [146942 rows x 2 columns]

# %%
zas_le = LabelEncoder()
zas_le.fit(df_sample["Zas"].astype(str))
df_sample["Zas_encoded"] = zas_le.transform(df_sample["Zas"].astype(str))
df_sample[["Zas", "Zas_encoded"]].head()
# Out:
#                                   Zas  Zas_encoded
# 337888  ZR PROVENCE-ALPES-COTE-D-AZUR            4
# 469825  ZR PROVENCE-ALPES-COTE-D-AZUR            4
# 366165                     ZAG TOULON            3
# 250011              ZAG MARSEILLE-AIX            1
# 723425                     ZAG TOULON            3

# %%
df_sample["validité"]
# Out:
# 337888    4
# 469825    1
# 366165    1
# 250011    1
# 723425    4
#          ..
# 161958    1
# 25423     1
# 52762     1
# 183000   -1
# 586192    1
# Name: validité, Length: 146942, dtype: int64

# %%
df_sample["is_valid"] = (df_sample["validité"] == 1).astype(int)
df_sample[["validité", "is_valid"]].head(20)
# Out:
#         validité  is_valid
# 337888         4         0
# 469825         1         1
# 366165         1         1
# 250011         1         1
# 723425         4         0
# 560356         1         1
# 215783         1         1
# 534512         1         1
# 179319         1         1
# 99624          1         1
# 139486         1         1
# 627927         1         1
# 486826         1         1
# 493542         1         1
# 217606         1         1
# 344357         4         0
# 201841         1         1
# 49844         -1         0
# 50796          1         1
# 730297         4         0

# %%
df_sample.columns
# Out:
# Index(['Date de début', 'Date de fin', 'Zas', 'code site',
#        'type d'implantation', 'Polluant', 'type d'influence', 'Réglementaire',
#        'type d'évaluation', 'type de valeur', 'valeur', 'unité de mesure',
#        'code qualité', 'validité', 'Latitude', 'Longitude', 'valeur_log',
#        'date', 'hour', 'day', 'month', 'year', 'weekday', 'is_weekend',
#        'week_of_year', 'day_of_year', 'season', 'time_of_day',
#        'Polluant_encoded', 'influence_encoded', 'implantation_encoded',
#        'site_encoded', 'Zas_encoded', 'is_valid'],
#       dtype='object')

# %%
df_sample["is_quality_A"] = (df_sample["code qualité"] == "A").astype(int)
df_sample[["code qualité", "is_quality_A"]].head()
# Out:
#        code qualité  is_quality_A
# 337888            A             1
# 469825            A             1
# 366165            A             1
# 250011            A             1
# 723425            A             1

# %%
df_sample = df_sample.sort_values("date")
df_sample
# Out:
#               Date de début          Date de fin  \
# 242945  2025-01-01 00:00:00  2025-01-01 01:00:00
# 242969  2025-01-01 00:00:00  2025-01-01 01:00:00
# 242825  2025-01-01 00:00:00  2025-01-01 01:00:00
# 262433  2025-01-01 00:00:00  2025-01-01 01:00:00
# 224177  2025-01-01 00:00:00  2025-01-01 01:00:00
# ...                     ...                  ...
# 568884  2025-11-19 19:00:00  2025-11-19 20:00:00
# 601183  2025-11-19 19:00:00  2025-11-19 20:00:00
# 590300  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578104  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578064  2025-11-19 19:00:00  2025-11-19 20:00:00
#
#                                   Zas code site     type d'implantation  \
# 242945  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03027  Rurale près des villes
# 242969              ZAG MARSEILLE-AIX   FR03029                 Urbaine
# 242825              ZAG MARSEILLE-AIX   FR02041                 Urbaine
# 262433              ZAG MARSEILLE-AIX   FR02004                 Urbaine
# ...

# %%
df_sample["lag_1"] = df_sample.groupby("Polluant")["valeur"].shift(1)
df_sample["lag_1"]
# Out:
# 242945     NaN
# 242969    21.1
# 242825    17.9
# 262433     NaN
# 224177     NaN
#           ...
# 568884     NaN
# 601183     5.1
# 590300     NaN
# 578104    68.5
# 578064    16.8
# Name: lag_1, Length: 146942, dtype: float64

# %%
df_sample[["date", "valeur", "lag_1"]].head(10)
# Out:
#              date  valeur  lag_1
# 242945 2025-01-01    21.1    NaN
# 242969 2025-01-01    17.9   21.1
# 242825 2025-01-01    74.4   17.9
# 262433 2025-01-01    35.8    NaN
# 224177 2025-01-01    33.0    NaN
# 224201 2025-01-01    19.9   33.0
# 224009 2025-01-01    28.3   19.9
# 262961 2025-01-01     3.9   35.8
# 262721 2025-01-01    10.4    3.9
# 262649 2025-01-01    42.0   10.4

# %%
df_sample
# Out:
#               Date de début          Date de fin  \
# 242945  2025-01-01 00:00:00  2025-01-01 01:00:00
# 242969  2025-01-01 00:00:00  2025-01-01 01:00:00
# 242825  2025-01-01 00:00:00  2025-01-01 01:00:00
# 262433  2025-01-01 00:00:00  2025-01-01 01:00:00
# 224177  2025-01-01 00:00:00  2025-01-01 01:00:00
# ...                     ...                  ...
# 568884  2025-11-19 19:00:00  2025-11-19 20:00:00
# 601183  2025-11-19 19:00:00  2025-11-19 20:00:00
# 590300  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578104  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578064  2025-11-19 19:00:00  2025-11-19 20:00:00
#
#                                   Zas code site     type d'implantation  \
# 242945  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03027  Rurale près des villes
# 242969              ZAG MARSEILLE-AIX   FR03029                 Urbaine
# 242825              ZAG MARSEILLE-AIX   FR02041                 Urbaine
# 262433              ZAG MARSEILLE-AIX   FR02004                 Urbaine
# ...

# %%
df_sample = df_sample.sort_values("date")
df_sample
# Out:
#               Date de début          Date de fin  \
# 242945  2025-01-01 00:00:00  2025-01-01 01:00:00
# 206154  2025-01-01 00:00:00  2025-01-01 01:00:00
# 224465  2025-01-01 00:00:00  2025-01-01 01:00:00
# 242753  2025-01-01 00:00:00  2025-01-01 01:00:00
# 206586  2025-01-01 00:00:00  2025-01-01 01:00:00
# ...                     ...                  ...
# 569004  2025-11-19 19:00:00  2025-11-19 20:00:00
# 590280  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578104  2025-11-19 19:00:00  2025-11-19 20:00:00
# 590360  2025-11-19 19:00:00  2025-11-19 20:00:00
# 578064  2025-11-19 19:00:00  2025-11-19 20:00:00
#
#                                   Zas code site     type d'implantation  \
# 242945  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03027  Rurale près des villes
# 206154              ZAG MARSEILLE-AIX   FR02041                 Urbaine
# 224465  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24033                 Urbaine
# 242753              ZAG MARSEILLE-AIX   FR02013             Périurbaine
# ...

# %%
df_sample["lag_24"] = df_sample.groupby("Polluant")["valeur"].shift(24)
df_sample[["date", "valeur", "lag_1", "lag_24"]].head(50-100)
# Out:
#                       date  valeur  lag_1  lag_24
# 242945 2025-01-01 00:00:00    21.1    NaN     NaN
# 206154 2025-01-01 00:00:00    78.1   23.1     NaN
# 224465 2025-01-01 00:00:00    36.2   32.3     NaN
# 242753 2025-01-01 00:00:00    76.2   34.5     NaN
# 206586 2025-01-01 00:00:00    23.1   42.7     NaN
# ...                    ...     ...    ...     ...
# 590417 2025-11-19 16:00:00    10.9    6.1     6.1
# 568781 2025-11-19 16:00:00     8.4   23.1    22.5
# 590337 2025-11-19 16:00:00    10.7    8.5     8.7
# 601440 2025-11-19 16:00:00    14.0   53.9    59.4
# 601320 2025-11-19 16:00:00    19.1   14.0    31.0
#
# [146892 rows x 4 columns]

# %%
df_sample["rolling_3"] = (
    df_sample
    .groupby("Polluant")["valeur"]
    .rolling(3, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)
df_sample[["date", "valeur", "rolling_3"]].head(15)
# Out:
#              date  valeur  rolling_3
# 242945 2025-01-01    21.1  21.100000
# 206154 2025-01-01    78.1  78.100000
# 224465 2025-01-01    36.2  36.200000
# 242753 2025-01-01    76.2  48.650000
# 206586 2025-01-01    23.1  50.600000
# 223985 2025-01-01    32.3  34.250000
# 241265 2025-01-01     NaN        NaN
# 262505 2025-01-01     0.9   0.900000
# 243209 2025-01-01    34.5  43.933333
# 262985 2025-01-01     2.2   1.550000
# 206346 2025-01-01    42.7  47.966667
# 262721 2025-01-01    10.4   4.500000
# 262961 2025-01-01     3.9   5.500000
# 224009 2025-01-01    28.3  32.266667
# 224201 2025-01-01    19.9  26.833333

# %%
df_sample["rolling_24"] = (
    df_sample
    .groupby("Polluant")["valeur"]
    .rolling(24, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)
df_sample[["date", "valeur", "rolling_24"]].head(30)
# Out:
#                       date  valeur  rolling_24
# 242945 2025-01-01 00:00:00    21.1   21.100000
# 206154 2025-01-01 00:00:00    78.1   78.100000
# 224465 2025-01-01 00:00:00    36.2   36.200000
# 242753 2025-01-01 00:00:00    76.2   48.650000
# 206586 2025-01-01 00:00:00    23.1   50.600000
# 223985 2025-01-01 00:00:00    32.3   34.250000
# 241265 2025-01-01 00:00:00     NaN         NaN
# 262505 2025-01-01 00:00:00     0.9    0.900000
# 243209 2025-01-01 00:00:00    34.5   43.933333
# 262985 2025-01-01 00:00:00     2.2    1.550000
# 206346 2025-01-01 00:00:00    42.7   47.966667
# 262721 2025-01-01 00:00:00    10.4    4.500000
# 262961 2025-01-01 00:00:00     3.9    4.350000
# 224009 2025-01-01 00:00:00    28.3   32.266667
# 224201 2025-01-01 00:00:00    19.9   29.175000
# 224177 2025-01-01 00:00:00    33.0   29.940000
# 262433 2025-01-01 00:00:00    35.8   10.640000
# 242825 2025-01-01 00:00:00    74.4   51.550000
# 242969 2025-01-01 00:00:00    17.9   44.820000
# ...

# %%
df_sample["date_only"] = df_sample["date"].dt.date

df_sample["daily_mean"] = (
    df_sample
    .groupby(["Polluant", "date_only"])["valeur"]
    .transform("mean")
)
df_sample[["date", "valeur", "daily_mean"]].head(20)
# Out:
#              date  valeur  daily_mean
# 242945 2025-01-01    21.1   23.915833
# 206154 2025-01-01    78.1   26.658065
# 224465 2025-01-01    36.2   25.658871
# 242753 2025-01-01    76.2   23.915833
# 206586 2025-01-01    23.1   26.658065
# 223985 2025-01-01    32.3   25.658871
# 241265 2025-01-01     NaN    0.299667
# 262505 2025-01-01     0.9   38.088636
# 243209 2025-01-01    34.5   23.915833
# 262985 2025-01-01     2.2   38.088636
# 206346 2025-01-01    42.7   26.658065
# 262721 2025-01-01    10.4   38.088636
# 262961 2025-01-01     3.9   38.088636
# 224009 2025-01-01    28.3   25.658871
# 224201 2025-01-01    19.9   25.658871
# 224177 2025-01-01    33.0   25.658871
# 262433 2025-01-01    35.8   38.088636
# 242825 2025-01-01    74.4   23.915833
# 242969 2025-01-01    17.9   23.915833
# 262649 2025-01-01    42.0   38.088636

# %%
pollutant_stats = df_sample.groupby("Polluant")["valeur"].agg(["median", "std"])
pollutant_stats
# Out:
#           median        std
# Polluant
# CO         0.184   0.096886
# NO2       11.900  14.300977
# O3        69.800  30.890295
# PM10      14.100  12.174744
# PM2.5      7.200   7.064143

# %%
df_sample = df_sample.merge(
    pollutant_stats,
    on="Polluant",
    how="left"
)
df_sample["is_spike"] = (df_sample["valeur"] > df_sample["median"] + 2 * df_sample["std"]).astype(int)
df_sample[["valeur", "median", "std", "is_spike"]].head(15)
# Out:
#     valeur  median        std  is_spike
# 0     21.1   7.200   7.064143         0
# 1     78.1  14.100  12.174744         1
# 2     36.2  11.900  14.300977         0
# 3     76.2   7.200   7.064143         1
# 4     23.1  14.100  12.174744         0
# 5     32.3  11.900  14.300977         0
# 6      NaN   0.184   0.096886         0
# 7      0.9  69.800  30.890295         0
# 8     34.5   7.200   7.064143         1
# 9      2.2  69.800  30.890295         0
# 10    42.7  14.100  12.174744         1
# 11    10.4  69.800  30.890295         0
# 12     3.9  69.800  30.890295         0
# 13    28.3  11.900  14.300977         0
# 14    19.9  11.900  14.300977         0

# %%
df_sample = df_sample.drop(columns=[
    "Date de fin",
    "unité de mesure",
    "Organisme"
], errors="ignore")

# %%
df_sample.columns
# Out:
# Index(['Date de début', 'Zas', 'code site', 'type d'implantation', 'Polluant',
#        'type d'influence', 'Réglementaire', 'type d'évaluation',
#        'type de valeur', 'valeur', 'code qualité', 'validité', 'Latitude',
#        'Longitude', 'valeur_log', 'date', 'hour', 'day', 'month', 'year',
#        'weekday', 'is_weekend', 'week_of_year', 'day_of_year', 'season',
#        'time_of_day', 'Polluant_encoded', 'influence_encoded',
#        'implantation_encoded', 'site_encoded', 'Zas_encoded', 'is_valid',
#        'is_quality_A', 'lag_1', 'lag_24', 'rolling_3', 'rolling_24',
#        'date_only', 'daily_mean', 'median', 'std', 'is_spike'],
#       dtype='object')

# %%
df_sample = df_sample.drop(columns=[
    "Polluant"
], errors="ignore")

# %%
df_sample = df_sample.drop(columns=[
    "nom site",
    "type d'implantation",
    "type d'influence",
    "Zas",
    "code site","validité","code qualité"
], errors="ignore")

# %%
df_sample = df_sample.drop(columns=[
    "taux de saisie",
    "couverture temporelle",
    "couverture de données"
], errors="ignore")

# %%
df_sample.columns
# Out:
# Index(['Date de début', 'Réglementaire', 'type d'évaluation', 'type de valeur',
#        'valeur', 'Latitude', 'Longitude', 'valeur_log', 'date', 'hour', 'day',
#        'month', 'year', 'weekday', 'is_weekend', 'week_of_year', 'day_of_year',
#        'season', 'time_of_day', 'Polluant_encoded', 'influence_encoded',
#        'implantation_encoded', 'site_encoded', 'Zas_encoded', 'is_valid',
#        'is_quality_A', 'lag_1', 'lag_24', 'rolling_3', 'rolling_24',
#        'date_only', 'daily_mean', 'median', 'std', 'is_spike'],
#       dtype='object')

# %%
df_sample.isna().sum()
# Out:
# Date de début              0
# Réglementaire              0
# type d'évaluation          0
# type de valeur             0
# valeur                  4659
# Latitude                   0
# Longitude                  0
# valeur_log              4659
# date                       0
# hour                       0
# day                        0
# month                      0
# year                       0
# weekday                    0
# is_weekend                 0
# week_of_year               0
# day_of_year                0
# season                     0
# time_of_day                0
# Polluant_encoded           0
# influence_encoded          0
# implantation_encoded       0
# site_encoded               0
# Zas_encoded                0
# is_valid                   0
# is_quality_A               0
# lag_1                   4662
# lag_24                  4767
# rolling_3                279
# rolling_24                 3
# date_only                  0
# daily_mean                18
# ...

# %%
df_sample = df_sample.dropna(subset=["valeur"])

# %%
df_sample.isna().sum()
# Out:
# Date de début              0
# Réglementaire              0
# type d'évaluation          0
# type de valeur             0
# valeur                     0
# Latitude                   0
# Longitude                  0
# valeur_log                 0
# date                       0
# hour                       0
# day                        0
# month                      0
# year                       0
# weekday                    0
# is_weekend                 0
# week_of_year               0
# day_of_year                0
# season                     0
# time_of_day                0
# Polluant_encoded           0
# influence_encoded          0
# implantation_encoded       0
# site_encoded               0
# Zas_encoded                0
# is_valid                   0
# is_quality_A               0
# lag_1                   3994
# lag_24                  4006
# rolling_3                  0
# rolling_24                 0
# date_only                  0
# daily_mean                 0
# ...

# %%
X = df_sample.drop(columns=["valeur"])
y = df_sample["valeur"]

# %%
split_index = int(len(df_sample) * 0.8)

X_train = X.iloc[:split_index]
X_test  = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test  = y.iloc[split_index:]

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# %%
X_train.dtypes[X_train.dtypes == "object"]
# Out:
# Date de début        object
# Réglementaire        object
# type d'évaluation    object
# type de valeur       object
# season               object
# time_of_day          object
# date_only            object
# dtype: object

# %%
df_sample = df_sample.drop(columns=[
    "Date de début",
    "date",
    "date_only"
], errors="ignore")

# %%
df_sample = pd.get_dummies(
    df_sample,
    columns=["season", "time_of_day"],
    drop_first=True
)

# %%
from sklearn.preprocessing import LabelEncoder

for col in ["Réglementaire", "type d'évaluation", "type de valeur"]:
    if df_sample[col].dtype == "object":
        le = LabelEncoder()
        df_sample[col] = le.fit_transform(df_sample[col].astype(str))

# %%
X = df_sample.drop(columns=["valeur"])
y = df_sample["valeur"]

# %%
split_index = int(len(df_sample) * 0.8)

X_train = X.iloc[:split_index]
X_test  = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test  = y.iloc[split_index:]

# %%
X_train.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('int32'), UInt32Dtype(),
#        dtype('bool')], dtype=object)

# %%
X_train = X_train.astype("float64")
X_test = X_test.astype("float64")

# %%
X_train.dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
from xgboost import XGBRegressor

model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R² Score:", r2)
# Out:
# MAE: 0.19809549038190968
# RMSE: 0.8728327569178888
# R² Score: 0.9987613990807351

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))
plt.plot(y_test.values[:300], label="Actual", linewidth=2)
plt.plot(y_pred[:300], label="Predicted", linewidth=2)
plt.legend()
plt.title("Actual vs Predicted Pollution (First 300 Test Samples)")
plt.xlabel("Time steps")
plt.ylabel("Pollution Level")
plt.show()

# %%
## FEATURE IMPORTANCE

# %%
import numpy as np

importances = model.feature_importances_
feature_names = X_train.columns

sorted_idx = np.argsort(importances)[::-1]

for idx in sorted_idx[:20]:   # Top 20 features
    print(f"{feature_names[idx]}: {importances[idx]}")
# Out:
# valeur_log: 0.6775833368301392
# rolling_3: 0.2166890799999237
# is_spike: 0.0457809753715992
# type d'évaluation: 0.012680497951805592
# median: 0.012298066169023514
# rolling_24: 0.008404500782489777
# Polluant_encoded: 0.006142449099570513
# site_encoded: 0.003821765538305044
# influence_encoded: 0.003225556341931224
# std: 0.0017528649186715484
# daily_mean: 0.0015780938556417823
# Latitude: 0.0012753542978316545
# time_of_day_morning: 0.0010460111079737544
# time_of_day_evening: 0.0008032689802348614
# time_of_day_night: 0.0007840016041882336
# month: 0.0007334007532335818
# is_quality_A: 0.0006958253215998411
# implantation_encoded: 0.0006432440713979304
# Longitude: 0.0006332117482088506
# Zas_encoded: 0.0006322915432974696

# %%
plt.figure(figsize=(10,6))
plt.barh(feature_names[sorted_idx][:20], importances[sorted_idx][:20])
plt.gca().invert_yaxis()
plt.title("Top 20 Feature Importances")
plt.show()

# %%
pollutants = df_sample["Polluant_encoded"].unique()
pollutants
# Out:
# array([4, 3, 1, 2, 0])

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

models = {}
scores = {}

for p in pollutants:
    print(f"\nTraining model for pollutant: {p}")
    
    df_p = df_sample[df_sample["Polluant_encoded"] == p].copy()
    
    # Split chronological
    split_i = int(len(df_p) * 0.8)
    
    X_p = df_p.drop(columns=["valeur"])
    y_p = df_p["valeur"]
    
    X_train_p = X_p.iloc[:split_i]
    X_test_p  = X_p.iloc[split_i:]
    y_train_p = y_p.iloc[:split_i]
    y_test_p  = y_p.iloc[split_i:]
    
    # Train model
    model_p = XGBRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=8,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    )
    
    model_p.fit(X_train_p, y_train_p)
    y_pred_p = model_p.predict(X_test_p)
    
    # Evaluate
    mae = mean_absolute_error(y_test_p, y_pred_p)
    rmse = np.sqrt(mean_squared_error(y_test_p, y_pred_p))
    r2   = r2_score(y_test_p, y_pred_p)
    
    models[p] = model_p
    scores[p] = {"MAE": mae, "RMSE": rmse, "R2": r2}
    
    print(f"Pollutant {p}: MAE={mae:.3f}, RMSE={rmse:.3f}, R²={r2:.4f}")
# Out:
# Training model for pollutant: 4
# Pollutant 4: MAE=0.072, RMSE=0.269, R²=0.9975
#
# Training model for pollutant: 3
# Pollutant 3: MAE=0.235, RMSE=2.279, R²=0.9640
#
# Training model for pollutant: 1
# Pollutant 3: MAE=0.235, RMSE=2.279, R²=0.9640
#
# Training model for pollutant: 1
# Pollutant 1: MAE=0.235, RMSE=0.594, R²=0.9983
#
# Training model for pollutant: 2
# Pollutant 1: MAE=0.235, RMSE=0.594, R²=0.9983
#
# Training model for pollutant: 2
# Pollutant 2: MAE=0.420, RMSE=0.746, R²=0.9992
#
# Training model for pollutant: 0
# Pollutant 2: MAE=0.420, RMSE=0.746, R²=0.9992
#
# Training model for pollutant: 0
# Pollutant 0: MAE=0.007, RMSE=0.030, R²=0.9254
# Pollutant 0: MAE=0.007, RMSE=0.030, R²=0.9254

# %%
import pandas as pd

next_hour_forecasts = {}

for p in pollutants:
    # Filter data for this pollutant and sort in time order
    df_p = df_sample[df_sample["Polluant_encoded"] == p].copy()
    df_p = df_p.sort_values(["year", "month", "day", "hour"])
    
    # Take the last known row (most recent hour)
    last_row = df_p.iloc[-1:].copy()
    
    # Drop target column to get features only
    X_last = last_row.drop(columns=["valeur"], errors="ignore")
    
    # Predict next hour pollution for this pollutant
    y_next = models[p].predict(X_last)[0]
    
    next_hour_forecasts[p] = y_next

next_hour_forecasts
# Out:
# {np.int64(4): np.float32(32.631912),
#  np.int64(3): np.float32(32.660328),
#  np.int64(1): np.float32(46.76999),
#  np.int64(2): np.float32(62.929317),
#  np.int64(0): np.float32(0.31244493)}

# %%
pollutant_names = pollutant_le.inverse_transform(list(next_hour_forecasts.keys()))

for pid, name in zip(next_hour_forecasts.keys(), pollutant_names):
    print(f"{name} (id={pid}) → next hour forecast: {next_hour_forecasts[pid]:.3f}")
# Out:
# PM2.5 (id=4) → next hour forecast: 32.632
# PM10 (id=3) → next hour forecast: 32.660
# NO2 (id=1) → next hour forecast: 46.770
# O3 (id=2) → next hour forecast: 62.929
# CO (id=0) → next hour forecast: 0.312

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
from lightgbm import LGBMRegressor
use_lightgbm = True
use_lightgbm = False

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    return mae, rmse, r2

# %%
models_to_test = {
    "XGBoost": XGBRegressor(
        n_estimators=300, learning_rate=0.05,
        max_depth=8, subsample=0.8, colsample_bytree=0.8,
        random_state=42
    ),

    "RandomForest": RandomForestRegressor(
        n_estimators=300, max_depth=20,
        random_state=42, n_jobs=-1
    )
}

if use_lightgbm:
    models_to_test["LightGBM"] = LGBMRegressor(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=-1,
        random_state=42
    )

# %%
results = {}

for name, model in models_to_test.items():
    print(f"\nTraining {name}...")
    mae, rmse, r2 = evaluate_model(model, X_train, y_train, X_test, y_test)
    results[name] = {"MAE": mae, "RMSE": rmse, "R2": r2}
    print(f"{name}: MAE={mae:.4f}, RMSE={rmse:.4f}, R²={r2:.4f}")
# Out:
# Training XGBoost...
# XGBoost: MAE=0.1981, RMSE=0.8728, R²=0.9988
#
# Training RandomForest...
# XGBoost: MAE=0.1981, RMSE=0.8728, R²=0.9988
#
# Training RandomForest...
# RandomForest: MAE=0.0059, RMSE=0.7249, R²=0.9991
# RandomForest: MAE=0.0059, RMSE=0.7249, R²=0.9991

# %%
import pandas as pd
comparison = pd.DataFrame(results).T
comparison
# Out:
#                    MAE      RMSE        R2
# XGBoost       0.198095  0.872833  0.998761
# RandomForest  0.005885  0.724886  0.999146

# %%
# !pip install shap
import shap
shap.initjs()
# Out:
# ...
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
importances = models_to_test["XGBoost"].feature_importances_
feature_names = X_train.columns

sorted_idx = importances.argsort()[::-1]
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import shap
import numpy as np

# use only the top 20 most important features
top_features = feature_names[sorted_idx][:20]

# take a smaller random sample of test data
X_test_small = X_test[top_features].sample(300, random_state=42)

# build SHAP explainer for RandomForest
explainer_rf = shap.TreeExplainer(models_to_test["RandomForest"])

# compute SHAP values on the small sample (FAST)
shap_values_rf = explainer_rf.shap_values(X_test_small)

# summary plot
shap.summary_plot(shap_values_rf, X_test_small, plot_type="dot")

# %%
shap.summary_plot(shap_values_rf, X_test_small, plot_type="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 shap.summary_plot(shap_values_rf, X_test_small, plot_type="bar")
#
# NameError: name 'shap_values_rf' is not defined

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(feature_names[sorted_idx][:20], importances[sorted_idx][:20])
plt.xlabel("Importance Score")
plt.title("Top 20 Most Important Features (XGBoost)")
plt.gca().invert_yaxis()
plt.show()
